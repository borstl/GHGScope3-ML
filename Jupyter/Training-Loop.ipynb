# %%
import sys
from pathlib import Path

import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from core import Config
import pandas as pd

from typing import cast, Sequence
from sklearn.model_selection import GroupKFold
from catboost import Pool, CatBoostRegressor

import shap
import matplotlib.pyplot as plt

sector_numbers: Sequence[int] = range(10, 61, 5)
config = Config()

for i in sector_numbers:
    print(f"Training sector {i}")
    DATASET: str = f'imputed_thresh_50_win_log_sector_{i}_verification-r'
    DATA_PATH: Path = config.training_dir / f'{DATASET}.csv'
    # variables
    DEPTH: int = 4
    ITERATIONS: int = 400
    LEARNING_RATE: float = 0.1
    FOLDS: int = 5
    ORDERED: str | None = "Ordered"
    #ORDERED: str | None = None
    SHUFFLE: bool = True
    STATE: int = 42
    RESULTS_NAME: str = f'{DEPTH}_{DATASET}'
    if ORDERED:
        RESULTS_NAME += f'_{ORDERED}'
    if SHUFFLE:
        RESULTS_NAME += f'_sh{STATE}'
    SHAP_NAME: str = f'{RESULTS_NAME}_shap_importance.csv'
    SHAP_PLOT_NAME: str = f'{RESULTS_NAME}_shap_beeswarm.png'

    all_data: pd.DataFrame = pd.read_csv(DATA_PATH, index_col=0)

    training_data = all_data.copy()
    training_data.drop(
        training_data[training_data["TR.UpstreamScope3PurchasedGoodsAndServices"].isna()].index,
        inplace=True
    )
    y: pd.DataFrame = training_data['TR.UpstreamScope3PurchasedGoodsAndServices'].to_frame()
    X: pd.DataFrame = training_data.drop('TR.UpstreamScope3PurchasedGoodsAndServices', axis=1)
    # date could also be a categorical variable
    cat_cols: list[str] = ["Instrument", "TR.GICSSectorCode", "TR.HQCountryCode"]
    cat_cols.remove("Instrument")
    # disable categorical features when using one-hot encoded datasets
    #cat_cols: list[str] = []
    X[cat_cols] = X[cat_cols].astype("str")

    gkf: GroupKFold = GroupKFold(n_splits=FOLDS, random_state=STATE, shuffle=SHUFFLE)
    fold_results: list[dict] = []

    best_fold_index: int | None = None
    best_metric_value: float | None = None  # lower is better (RMSE)
    best_model: CatBoostRegressor = CatBoostRegressor()
    best_X_val: pd.DataFrame | None = None
    best_y_val: pd.Series | None = None

    for fold_index, (train_index, val_index) in enumerate(gkf.split(X, y, groups=X['Instrument']), start=1):
        print(f"Fold {fold_index}")
        X_without_instrument = X.drop(columns=["Instrument"])
        X_train: pd.DataFrame = cast(pd.DataFrame, X_without_instrument.iloc[train_index])
        #    X_train: pd.DataFrame = cast(pd.DataFrame, X.iloc[train_index])
        X_val: pd.DataFrame = cast(pd.DataFrame, X_without_instrument.iloc[val_index])
        #    X_val: pd.DataFrame = cast(pd.DataFrame, X.iloc[val_index])
        y_train: pd.Series[float] = cast(pd.Series, y.iloc[train_index])
        y_val: pd.Series[float] = cast(pd.Series, y.iloc[val_index])

        train_pool: Pool = Pool(
            data=X_train,
            label=y_train,
            cat_features=cat_cols
        )

        val_pool: Pool = Pool(
            data=X_val,
            label=y_val,
            cat_features=cat_cols
        )

        model = CatBoostRegressor(
            iterations=ITERATIONS,
            learning_rate=LEARNING_RATE,
            depth=DEPTH,
            loss_function='RMSE',
            eval_metric='R2',
            use_best_model=True,
            verbose=False,
            early_stopping_rounds=50,
            boosting_type=ORDERED,
        )

        model.fit(
            train_pool,
            eval_set=val_pool,
        )

        y_val_pred: list[float] = model.predict(val_pool)

        rmse: float = float(np.sqrt(mean_squared_error(y_val, y_val_pred)))
        mae: float = cast(float, mean_absolute_error(y_val, y_val_pred))
        r2: float = r2_score(y_val, y_val_pred)

        best_iter = model.get_best_iteration()

        if best_iter is None:
            print(f"Model ran full {ITERATIONS} iterations (no early stopping).")
            sys.exit()
        elif best_iter + 1 >= ITERATIONS:
            print(f"Model needed all {ITERATIONS} iterations (no earlier convergence).")
            sys.exit()
        else:
            print(f"Model converged earlier at iteration {best_iter + 1} of {ITERATIONS}.")

        fold_results.append(
            {
                "model_name": RESULTS_NAME,
                "fold": fold_index,
                "sector": "All",
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
            }
        )

        # update best model based on RMSE
        if (best_metric_value is None) or (rmse < best_metric_value):
            best_metric_value = rmse
            best_fold_index = fold_index
            best_model = model
            best_X_val = X_val.copy()
            best_y_val = y_val.copy()

        val_sectors: pd.Series = X_val["TR.GICSSectorCode"].astype("category")

        val_sectors = X_val["TR.GICSSectorCode"]
        val_df: pd.DataFrame = pd.DataFrame(
            {
                "y_true": y_val.to_numpy().ravel(),
                "y_pred": y_val_pred,
                "sector": val_sectors.to_numpy().ravel(),
            }
        )

        for sector, grp in val_df.groupby("sector"):
            rmse = float(np.sqrt(mean_squared_error(grp["y_true"], grp["y_pred"])))
            mae = cast(float, mean_absolute_error(grp["y_true"], grp["y_pred"]))
            r2 = r2_score(grp["y_true"], grp["y_pred"])

            fold_results.append(
                {
                    "model_name": RESULTS_NAME,
                    "fold": fold_index,
                    "sector": sector,
                    "rmse": rmse,
                    "mae": mae,
                    "r2": r2,
                }
            )

    print(f"Best fold by RMSE: {best_fold_index} (RMSE={best_metric_value:.2f})")
    metrics_df: pd.DataFrame = pd.DataFrame(fold_results)

    metrics_df.to_csv(config.results_dir / f'{RESULTS_NAME}_metrics.csv')
    best_model.save_model(f'{config.results_dir}/model/{RESULTS_NAME}_model.bin')

    # ---- SHAP for best fold only ----
    assert best_model is not None
    assert best_X_val is not None
    assert best_y_val is not None

    best_val_pool: Pool = Pool(
        data=best_X_val,
        label=best_y_val,
        cat_features=cat_cols,
    )

    feature_names = best_model.feature_names_

    shap_values = best_model.get_feature_importance(
        data=best_val_pool,
        type="ShapValues",
    )

    # drop expected value column
    shap_contribs = shap_values[:, :-1]

    shap_best_df = pd.DataFrame(
        shap_contribs,
        columns=feature_names,
        index=best_X_val.index,
    )

    # mean absolute SHAP over all validation observations of the best fold
    shap_best_importance = shap_best_df.abs().mean(axis=0).sort_values(ascending=False)

    shap_best_with_sector = shap_best_df.copy()
    shap_best_with_sector["sector"] = best_X_val["TR.GICSSectorCode"].astype(str).values

    feature_cols = [c for c in shap_best_with_sector.columns if c != "sector"]

    # mean absolute SHAP per feature, per sector
    shap_sector_best = (
        shap_best_with_sector[feature_cols]
        .abs()
        .groupby(shap_best_with_sector["sector"])
        .mean()
    )
    # combine shap_sector_best with shap_best_importance
    shap_best_row = shap_best_importance.to_frame().T
    shap_best_row.index = ["All"]
    shap_best_row = shap_best_row[shap_sector_best.columns]
    shap_importance_with_all = pd.concat(
        [shap_sector_best, shap_best_row],
        axis=0,
    )

    expl = shap.Explanation(
        values=shap_contribs,
        base_values=shap_values[:, -1],
        data=best_X_val[feature_names].to_numpy(),
        feature_names=feature_names,
    )
    plt.figure(figsize=(8, 6))
    shap.plots.beeswarm(expl, max_display=10, show=False)
    fig = plt.gcf()

    fig.savefig(
        config.results_dir / SHAP_PLOT_NAME,
        bbox_inches="tight",
        dpi=300,
        format="png"
    )

    plt.close(fig)

    new_metrics_group = metrics_df.groupby(["sector"]).agg(
        {
            "rmse": ["mean", "std"],
            "mae": ["mean", "std"],
            "r2": ["mean", "std"],
        }
    )

    shap_importance_with_all.to_csv(config.results_dir / SHAP_NAME, index=True)
# Out:
# Training sector 10
# Fold 1
# Model converged earlier at iteration 31 of 400.
# Fold 2
# Model converged earlier at iteration 45 of 400.
# Fold 3
# Model converged earlier at iteration 16 of 400.
# Fold 4
# Model converged earlier at iteration 17 of 400.
# Fold 5
# Model converged earlier at iteration 29 of 400.
# Best fold by RMSE: 2 (RMSE=1.19)
# Training sector 15
# Fold 1
# Model converged earlier at iteration 23 of 400.
# Fold 2
# Model converged earlier at iteration 127 of 400.
# Fold 3
# Model converged earlier at iteration 98 of 400.
# Fold 4
# Model converged earlier at iteration 70 of 400.
# Fold 5
# Model converged earlier at iteration 53 of 400.
# Best fold by RMSE: 5 (RMSE=1.02)
# Training sector 20
# Fold 1
# Model converged earlier at iteration 109 of 400.
# Fold 2
# Model converged earlier at iteration 150 of 400.
# Fold 3
# Model converged earlier at iteration 62 of 400.
# Fold 4
# Model converged earlier at iteration 322 of 400.
# Fold 5
# Model converged earlier at iteration 132 of 400.
# Best fold by RMSE: 4 (RMSE=1.37)
# Training sector 25
# Fold 1
# Model converged earlier at iteration 262 of 400.
# Fold 2
# Model converged earlier at iteration 76 of 400.
# Fold 3
# Model converged earlier at iteration 17 of 400.
# Fold 4
# Model converged earlier at iteration 94 of 400.
# Fold 5
# Model converged earlier at iteration 63 of 400.
# Best fold by RMSE: 3 (RMSE=1.30)
# Training sector 30
# Fold 1
# Model converged earlier at iteration 21 of 400.
# Fold 2
# Model converged earlier at iteration 20 of 400.
# Fold 3
# Model converged earlier at iteration 109 of 400.
# Fold 4
# Model converged earlier at iteration 43 of 400.
# Fold 5
# Model converged earlier at iteration 24 of 400.
# Best fold by RMSE: 2 (RMSE=1.62)
# Training sector 35
# Fold 1
# Model converged earlier at iteration 47 of 400.
# Fold 2
# Model converged earlier at iteration 29 of 400.
# Fold 3
# Model converged earlier at iteration 60 of 400.
# Fold 4
# Model converged earlier at iteration 23 of 400.
# Fold 5
# Model converged earlier at iteration 26 of 400.
# Best fold by RMSE: 1 (RMSE=1.19)
# Training sector 40
# Fold 1
# Model converged earlier at iteration 148 of 400.
# Fold 2
# Model converged earlier at iteration 168 of 400.
# Fold 3
# Model converged earlier at iteration 5 of 400.
# Fold 4
# Model converged earlier at iteration 52 of 400.
# Fold 5
# Model converged earlier at iteration 73 of 400.
# Best fold by RMSE: 4 (RMSE=2.01)
# Training sector 45
# Fold 1
# Model converged earlier at iteration 24 of 400.
# Fold 2
# Model converged earlier at iteration 75 of 400.
# Fold 3
# Model converged earlier at iteration 26 of 400.
# Fold 4
# Model converged earlier at iteration 85 of 400.
# Fold 5
# Model converged earlier at iteration 285 of 400.
# Best fold by RMSE: 1 (RMSE=1.67)
# Training sector 50
# Fold 1
# Model converged earlier at iteration 11 of 400.
# Fold 2
# Model converged earlier at iteration 77 of 400.
# Fold 3
# Model converged earlier at iteration 45 of 400.
# Fold 4
# Model converged earlier at iteration 15 of 400.
# Fold 5
# Model converged earlier at iteration 58 of 400.
# Best fold by RMSE: 5 (RMSE=1.81)
# Training sector 55
# Fold 1
# Model converged earlier at iteration 11 of 400.
# Fold 2
# Model converged earlier at iteration 16 of 400.
# Fold 3
# Model converged earlier at iteration 50 of 400.
# Fold 4
# Model converged earlier at iteration 26 of 400.
# Fold 5
# Model converged earlier at iteration 9 of 400.
# Best fold by RMSE: 2 (RMSE=1.84)
# Training sector 60
# Fold 1
# Model converged earlier at iteration 13 of 400.
# Fold 2
# Model converged earlier at iteration 14 of 400.
# Fold 3
# Model converged earlier at iteration 17 of 400.
# Fold 4
# Model converged earlier at iteration 325 of 400.
# Fold 5
# Model converged earlier at iteration 37 of 400.
# Best fold by RMSE: 1 (RMSE=2.09)
