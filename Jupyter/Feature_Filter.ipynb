# %%
from pathlib import Path

from scipy.interpolate import interpn

from data.constants import data_item_codes
from data.constants.data_item_codes import HISTORIC_DATA_ITEM_CODES, SMALL_HISTORIC_DATA_ITEM_CODES


def find_substrings(strings: set[str]) -> list[set[str]]:
    """
    Checks all strings for substrings within the set and
    returns a list of dicts describing matches.

    Each dict entry looks like:
    {'substring': <substring>, 'string': <string>}
    """
    results: list[set[str]] = []
    for s in strings:
        for t in strings:
            if s != t and s in t:  # skip identical comparisons
                results.append({s, t})
    return results

# Example usage:
substrings: list[set[str]] = find_substrings(HISTORIC_DATA_ITEM_CODES)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pathlib import Path
# ----> 3 from scipy.interpolate import interpn
#       5 from data.constants import data_item_codes
#       6 from data.constants.data_item_codes import HISTORIC_DATA_ITEM_CODES, SMALL_HISTORIC_DATA_ITEM_CODES
#
# File ~/PycharmProjects/ML/.venv/lib/python3.14/site-packages/scipy/interpolate/__init__.py:192
#       1 """
#       2 ========================================
#       3 Interpolation (:mod:`scipy.interpolate`)
#    (...)    190
#     191 """  # noqa: E501
# --> 192 from ._interpolate import *
#     193 from ._fitpack_py import *
#     195 from ._fitpack2 import *
#
# File ~/PycharmProjects/ML/.venv/lib/python3.14/site-packages/scipy/interpolate/_interpolate.py:15
#      11 from scipy.special import comb
# ...

# %%
# check for 'score' substring in list
sum = 0
for k, v in substrings:
    if 'Score' in v:
        sum +=1
        print(k, v)

# %%
# Check for .F. variants

# %%
# Check JP variants

# %%
# Check for
# \dYr
# CAGR
# Day
# Week
# Month
# Average
# Price

import re

def remove_items(dic: set[str], regex: str) -> set[str]:
    """Remove all items containing '[0-9]YrAvg' from the set"""
    removable_items: set[str] = {
        item for item in dic if re.search(regex, item)
    }
    print(f"Removing {len(removable_items)} items")
    return dic - removable_items

data_item_codes = remove_items(HISTORIC_DATA_ITEM_CODES, r'\dYr')
data_item_codes = remove_items(data_item_codes, r'CAGR')
data_item_codes = remove_items(data_item_codes, r'Day')
data_item_codes = remove_items(data_item_codes, r'Week')
data_item_codes = remove_items(data_item_codes, r'Month')
data_item_codes = remove_items(data_item_codes, r'Average')
data_item_codes = remove_items(data_item_codes, r'Price')
data_item_codes = remove_items(data_item_codes, r'Prev')
data_item_codes = remove_items(data_item_codes, r'Date')
data_item_codes = remove_items(data_item_codes, r'Period')
data_item_codes = remove_items(data_item_codes, r'Volume')
data_item_codes = remove_items(data_item_codes, r'High')
data_item_codes = remove_items(data_item_codes, r'Low')
data_item_codes = remove_items(data_item_codes, r'Mean')
data_item_codes = remove_items(data_item_codes, r'Std')
data_item_codes = remove_items(data_item_codes, r'Median')
data_item_codes = remove_items(data_item_codes, r'Audit')
data_item_codes = remove_items(data_item_codes, r'Contact')
data_item_codes = remove_items(data_item_codes, r'Est')
data_item_codes = remove_items(data_item_codes, r'Score')
data_item_codes = remove_items(data_item_codes, r'PRICE')
data_item_codes = remove_items(data_item_codes, r'Board')
data_item_codes = remove_items(data_item_codes, r'JP')
data_item_codes = remove_items(data_item_codes, r'.F.')

# %%
import json

#historic_def = {}
#small_historic_def = {}
#static_def = {}
with open('../data/datasets/definitions/unloaded_historic_definitions_progress.json', 'r') as f:
    empty_def = json.load(f)
#with open('../data/datasets/unloaded_small_historic_definitions_progress.json', 'r') as f:
#    empty_def = json.load(f)
#with open('../data/datasets/unloaded_static_definitions_progress.json', 'r') as f:
#    empty_def = json.load(f)

res = [k for k, v in empty_def.items() if v == 'No item selected' or v is None]

# %%
import json
from core.config import Config
config = Config()

small_historic_def = {}
with open(config.dataset_dir / 'definitions' / 'selected_timeseries_definitions.json', 'r') as f:
    small_historic_def = json.load(f)

large_historic_def = {}
with open(config.dataset_dir / 'definitions' / 'rest_timeseries_definitions.json', 'r') as f:
    large_historic_def = json.load(f)

small_historic_def.update(large_historic_def)

res = [k for k, v in small_historic_def.items() if v == 'No item selected' or v is None]

with open(config.dataset_dir / 'definitions' / 'timeseries_definitions.json', 'w') as f:
    json.dump(small_historic_def, f, indent=2)

# %%
from core.config import Config
from data.constants import features
config = Config()

res = features.additional_features & features.time_series_features

# %%
import pandas as pd
from core.config import Config

config = Config()
df: pd.DataFrame = pd.read_csv(config.dataset_dir / 'median' / 'combined_selected.csv')

features = df.columns
